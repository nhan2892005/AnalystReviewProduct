# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
query = """
SELECT 1 as number;
"""

pd.read_sql(query, con=engine)
# Out:
#    number
# 0       1

# %%
query = """
SELECT *
FROM pg_catalog.pg_tables;
"""

pd.read_sql(query, con=engine)
# Out:
#             schemaname                tablename tableowner tablespace  \
# 0               public         green_taxi_trips       root       None
# 1           pg_catalog             pg_statistic       root       None
# 2           pg_catalog                  pg_type       root       None
# 3           pg_catalog         pg_foreign_table       root       None
# 4           pg_catalog                pg_authid       root  pg_global
# ..                 ...                      ...        ...        ...
# 62          pg_catalog      pg_subscription_rel       root       None
# 63  information_schema  sql_implementation_info       root       None
# 64  information_schema                sql_parts       root       None
# 65  information_schema               sql_sizing       root       None
# 66  information_schema             sql_features       root       None
#
#     hasindexes  hasrules  hastriggers  rowsecurity
# 0        False     False        False        False
# 1         True     False        False        False
# 2         True     False        False        False
# 3         True     False        False        False
# 4         True     False        False        False
# ..         ...       ...          ...          ...
# 62        True     False        False        False
# 63       False     False        False        False
# 64       False     False        False        False
# 65       False     False        False        False
# 66       False     False        False        False
#
# [67 rows x 8 columns]

# %%
df = pd.read_csv('./data/green_tripdata_2024-01.csv')

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3640\1874911345.py in ?()
# ----> 1 df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
#       2 df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'tpep_pickup_datetime'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               100 non-null    int64
#  1   lpep_pickup_datetime   100 non-null    object
#  2   lpep_dropoff_datetime  100 non-null    object
#  3   store_and_fwd_flag     100 non-null    object
#  4   RatecodeID             100 non-null    float64
#  5   PULocationID           100 non-null    int64
#  6   DOLocationID           100 non-null    int64
#  7   passenger_count        100 non-null    float64
#  8   trip_distance          100 non-null    float64
#  9   fare_amount            100 non-null    float64
#  10  extra                  100 non-null    float64
#  11  mta_tax                100 non-null    float64
#  12  tip_amount             100 non-null    float64
#  13  tolls_amount           100 non-null    float64
#  14  ehail_fee              0 non-null      float64
#  15  improvement_surcharge  100 non-null    float64
#  16  total_amount           100 non-null    float64
#  17  payment_type           100 non-null    float64
#  18  trip_type              100 non-null    float64
#  19  congestion_surcharge   100 non-null    float64
# dtypes: float64(14), int64(3), object(3)
# memory usage: 15.8+ KB

# %%
df.to_sql(name='green_taxi_trips', con=engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.to_sql(name='green_taxi_trips', con=engine, index=False)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py:3008, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2813 """
#    2814 Write records stored in a DataFrame to a SQL database.
#    2815
#    (...)
#    3004 [(1,), (None,), (2,)]
#    3005 """  # noqa: E501
#    3006 from pandas.io import sql
# -> 3008 return sql.to_sql(
#    3009     self,
#    3010     name,
#    3011     con,
#    3012     schema=schema,
#    3013     if_exists=if_exists,
#    3014     index=index,
#    3015     index_label=index_label,
#    3016     chunksize=chunksize,
#    3017     dtype=dtype,
#    3018     method=method,
#    3019 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\sql.py:788, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     783     raise NotImplementedError(
#     784         "'frame' argument should be either a Series or a DataFrame"
#     785     )
#     787 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 788     return pandas_sql.to_sql(
#     789         frame,
#     790         name,
#     791         if_exists=if_exists,
#     792         index=index,
#     793         index_label=index_label,
#     794         schema=schema,
#     795         chunksize=chunksize,
#     796         dtype=dtype,
#     797         method=method,
#     798         engine=engine,
#     799         **engine_kwargs,
#     800     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\sql.py:1948, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1898 """
#    1899 Write records stored in a DataFrame to a SQL database.
#    1900
#    (...)
#    1944     Any additional kwargs are passed to the engine.
#    1945 """
#    1946 sql_engine = get_engine(engine)
# -> 1948 table = self.prep_table(
#    1949     frame=frame,
#    1950     name=name,
#    1951     if_exists=if_exists,
#    1952     index=index,
#    1953     index_label=index_label,
#    1954     schema=schema,
#    1955     dtype=dtype,
#    1956 )
#    1958 total_inserted = sql_engine.insert_records(
#    1959     table=table,
#    1960     con=self.con,
#    (...)
#    1967     **engine_kwargs,
#    1968 )
#    1970 self.check_case_sensitive(name=name, schema=schema)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\sql.py:1852, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1840             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1842 table = SQLTable(
#    1843     name,
#    1844     self,
#    (...)
#    1850     dtype=dtype,
#    1851 )
# -> 1852 table.create()
#    1853 return table
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\sql.py:927, in SQLTable.create(self)
#     925 if self.exists():
#     926     if self.if_exists == "fail":
# --> 927         raise ValueError(f"Table '{self.name}' already exists.")
#     928     if self.if_exists == "replace":
#     929         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'green_taxi_trips' already exists.

# %%
query = """
SELECT * FROM green_taxi_trips LIMIT 10
"""

pd.read_sql(query, con=engine)
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2024-01-01 00:46:55   2024-01-01 00:58:25                  N
# 1         2  2024-01-01 00:31:42   2024-01-01 00:52:34                  N
# 2         2  2024-01-01 00:30:21   2024-01-01 00:49:23                  N
# 3         1  2024-01-01 00:30:20   2024-01-01 00:42:12                  N
# 4         2  2024-01-01 00:32:38   2024-01-01 00:43:37                  N
# 5         1  2024-01-01 00:43:41   2024-01-01 01:00:23                  N
# 6         1  2024-01-01 00:31:56   2024-01-01 00:48:09                  N
# 7         2  2024-01-01 00:46:12   2024-01-01 00:57:39                  N
# 8         2  2024-01-01 00:38:07   2024-01-01 00:39:23                  N
# 9         2  2024-01-01 00:44:24   2024-01-01 00:57:47                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0           236           239              1.0           1.98
# 1         1.0            65           170              5.0           6.54
# 2         1.0            74           262              1.0           3.08
# 3         1.0            74           116              1.0           2.40
# 4         1.0            74           243              1.0           5.14
# 5         1.0            33           209              1.0           2.00
# 6         1.0            74           238              2.0           3.20
# 7         1.0           166           239              2.0           2.01
# 8         1.0           226           226              1.0           0.31
# 9         1.0             7           129              1.0           2.32
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# 0         12.8   1.00      0.5        3.61           0.0      None
# 1         30.3   1.00      0.5        7.11           0.0      None
# 2         19.8   1.00      0.5        3.00           0.0      None
# 3         14.2   1.00      1.5        0.00           0.0      None
# 4         22.6   1.00      0.5        6.28           0.0      None
# 5         17.0   3.75      1.5        2.00           0.0      None
# 6         18.4   3.75      1.5        4.70           0.0      None
# 7         13.5   1.00      0.5        5.62           0.0      None
# 8          3.7   1.00      0.5        0.00           0.0      None
# 9         14.9   1.00      0.5        3.48           0.0      None
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0         21.66           1.0        1.0
# 1                    1.0         42.66           1.0        1.0
# 2                    1.0         28.05           1.0        1.0
# 3                    1.0         16.70           2.0        1.0
# 4                    1.0         31.38           1.0        1.0
# 5                    1.0         24.25           1.0        1.0
# 6                    1.0         28.35           1.0        1.0
# 7                    1.0         24.37           1.0        1.0
# 8                    1.0          6.20           2.0        1.0
# 9                    1.0         20.88           1.0        1.0
#
#    congestion_surcharge
# 0                  2.75
# 1                  2.75
# 2                  2.75
# 3                  0.00
# 4                  0.00
# 5                  2.75
# 6                  2.75
# 7                  2.75
# 8                  0.00
# 9                  0.00
